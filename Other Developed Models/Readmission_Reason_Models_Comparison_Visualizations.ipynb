# %% [markdown]
# ### Below graphs show the comparison of the F1-scores between various models for both the training and testing datasets

# %% [markdown]
# ### 1) Traditional Models -
# #### Logistic Regression, Decision tree, and KNN

# %%
import matplotlib.pyplot as plt
import numpy as np

# Conditions and F1-scores for the Random Forest classifier
conditions = [
    'Conditions in the Perinatal Period',
    'Diseases of the Blood and Blood-forming Organs',
    'Diseases of the Circulatory System',
    'Diseases of the Digestive System',
    'Diseases of the Genitourinary System',
    'Diseases of the Nervous System & Mental Disorders',
    'Diseases of the Respiratory System',
    'Immunity Disorders and Musculoskeletal diseases',
    'Infectious & Parasitic Diseases',
    'Injury & Poisoning',
    'Symptoms, Signs and Ill-defined Conditions'
]

# F1-scores for training set
f1_scores_rf_train = [0.81, 0.70, 0.96, 0.69, 0.80, 0.77, 0.82, 0.92, 0.69, 0.74, 0.67]
f1_scores_rf_tuned_train = [0.81, 0.69, 0.94, 0.68, 0.76, 0.73, 0.78, 0.91, 0.68, 0.74, 0.63]

# F1-scores for testing set
f1_scores_rf_test = [0.76, 0.68, 0.92, 0.65, 0.74, 0.71, 0.79, 0.89, 0.66, 0.70, 0.61]
f1_scores_rf_tuned_test = [0.75, 0.66, 0.91, 0.63, 0.72, 0.69, 0.77, 0.88, 0.65, 0.69, 0.60]

# Create training plot
plt.figure(figsize=(12, 6))
plt.plot(conditions, f1_scores_rf_train, marker='o', linestyle='-', label='Random Forest Train')
plt.plot(conditions, f1_scores_rf_tuned_train, marker='s', linestyle='--', label='Random Forest Tuned Train')

# Add title and labels for training plot
plt.title('Training F1-Scores of Random Forest Models for Each Condition')
plt.xlabel('Conditions')
plt.ylabel('F1-Score')
plt.ylim(0.5, 1)
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()

# Create testing plot
plt.figure(figsize=(12, 6))
plt.plot(conditions, f1_scores_rf_test, marker='o', linestyle='-', label='Random Forest Test')
plt.plot(conditions, f1_scores_rf_tuned_test, marker='s', linestyle='--', label='Random Forest Tuned Test')

# Add title and labels for testing plot
plt.title('Testing F1-Scores of Random Forest Models for Each Condition')
plt.xlabel('Conditions')
plt.ylabel('F1-Score')
plt.ylim(0.5, 1)
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2) bagging Methods -
# #### Random Forest and Tuned Random forest using Hyperparameters

# %%
import matplotlib.pyplot as plt
import numpy as np

# Conditions and F1-scores for the Random Forest classifier
conditions = [
    'Conditions in the Perinatal Period',
    'Diseases of the Blood and Blood-forming Organs',
    'Diseases of the Circulatory System',
    'Diseases of the Digestive System',
    'Diseases of the Genitourinary System',
    'Diseases of the Nervous System & Mental Disorders',
    'Diseases of the Respiratory System',
    'Immunity Disorders and Musculoskeletal diseases',
    'Infectious & Parasitic Diseases',
    'Injury & Poisoning',
    'Symptoms, Signs and Ill-defined Conditions'
]

# F1-scores for training set
f1_scores_rf_train = [0.81, 0.70, 0.96, 0.69, 0.80, 0.77, 0.82, 0.92, 0.69, 0.74, 0.67]
f1_scores_rf_tuned_train = [0.81, 0.69, 0.94, 0.68, 0.76, 0.73, 0.78, 0.91, 0.68, 0.74, 0.63]

# F1-scores for testing set
f1_scores_rf_test = [0.76, 0.68, 0.92, 0.65, 0.74, 0.71, 0.79, 0.89, 0.66, 0.70, 0.61]
f1_scores_rf_tuned_test = [0.75, 0.66, 0.91, 0.63, 0.72, 0.69, 0.77, 0.88, 0.65, 0.69, 0.60]

# Create training plot
plt.figure(figsize=(12, 6))
plt.plot(conditions, f1_scores_rf_train, marker='o', linestyle='-', label='Random Forest Train')
plt.plot(conditions, f1_scores_rf_tuned_train, marker='s', linestyle='--', label='Random Forest Tuned Train')

# Add title and labels for training plot
plt.title('Training F1-Scores of Random Forest Models for Each Condition')
plt.xlabel('Conditions')
plt.ylabel('F1-Score')
plt.ylim(0.5, 1)
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()

# Create testing plot
plt.figure(figsize=(12, 6))
plt.plot(conditions, f1_scores_rf_test, marker='o', linestyle='-', label='Random Forest Test')
plt.plot(conditions, f1_scores_rf_tuned_test, marker='s', linestyle='--', label='Random Forest Tuned Test')

# Add title and labels for testing plot
plt.title('Testing F1-Scores of Random Forest Models for Each Condition')
plt.xlabel('Conditions')
plt.ylabel('F1-Score')
plt.ylim(0.5, 1)
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3) Ensemble Methods -
# #### Gradient Boosting, Extreme Graident Boosting, and Cat boosting

# %%
import matplotlib.pyplot as plt
import numpy as np

# Conditions and F1-scores for the three boosting models
conditions = [
    'Certain Conditions in the Perinatal Period',
    'Diseases of the Blood and Blood-forming Organs',
    'Diseases of the Circulatory System',
    'Diseases of the Digestive System',
    'Diseases of the Genitourinary System',
    'Diseases of the Nervous System & Mental Disorders',
    'Diseases of the Respiratory System',
    'Immunity Disorders & Musculoskeletal diseases',
    'Infectious & Parasitic Diseases',
    'Injury & Poisoning',
    'Symptoms,Signs and Ill-defined Conditions'
]

f1_scores_gb_train = [0.81, 0.30, 0.95, 0.50, 0.75, 0.72, 0.78, 0.89, 0.56, 0.65, 0.58]
f1_scores_xgb_train = [0.54, 0.47, 0.94, 0.49, 0.75, 0.71, 0.76, 0.89, 0.55, 0.65, 0.58]
f1_scores_cb_train = [0.81, 0.63, 0.95, 0.65, 0.77, 0.75, 0.80, 0.91, 0.65, 0.70, 0.64]

f1_scores_gb_test = [0.74, 0.23, 0.94, 0.45, 0.74, 0.69, 0.75, 0.89, 0.50, 0.63, 0.52]
f1_scores_xgb_test = [0.61, 0.43, 0.94, 0.45, 0.75, 0.69, 0.74, 0.88, 0.50, 0.63, 0.53]
f1_scores_cb_test = [0.76, 0.53, 0.95, 0.60, 0.74, 0.69, 0.76, 0.89, 0.56, 0.66, 0.55]

# Plotting Training Performance
plt.figure(figsize=(12, 6))
plt.plot(conditions, f1_scores_gb_train, marker='o', linestyle='-', label='Gradient Boosting')
plt.plot(conditions, f1_scores_xgb_train, marker='s', linestyle='--', label='XGBoost')
plt.plot(conditions, f1_scores_cb_train, marker='^', linestyle='-.', label='CatBoost')
plt.title('Training F1-Scores of Boosting Models for Each Condition')
plt.xlabel('Conditions')
plt.ylabel('F1-Score')
plt.ylim(0.2, 1)
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting Testing Performance
plt.figure(figsize=(12, 6))
plt.plot(conditions, f1_scores_gb_test, marker='o', linestyle='-', label='Gradient Boosting')
plt.plot(conditions, f1_scores_xgb_test, marker='s', linestyle='--', label='XGBoost')
plt.plot(conditions, f1_scores_cb_test, marker='^', linestyle='-.', label='CatBoost')
plt.title('Testing F1-Scores of Boosting Models for Each Condition')
plt.xlabel('Conditions')
plt.ylabel('F1-Score')
plt.ylim(0.2, 1)
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4) Advanced Models
# #### Fully Connected Neural Network (FCNN), FCNN with Attention Mechanism, Tuned FCNN using Keras Tuner, and Tuned FCNN using Random Search

# %%
import matplotlib.pyplot as plt

# Labels for the conditions
labels = [
    'Certain Conditions in the Perinatal Period',
    'Diseases of the Blood and Blood-forming Organs',
    'Diseases of the Circulatory System',
    'Diseases of the Digestive System',
    'Diseases of the Genitourinary System',
    'Diseases of the Nervous System & Mental Disorders',
    'Diseases of the Respiratory System',
    'Immunity Disorders & Musculoskeletal diseases',
    'Infectious & Parasitic Diseases',
    'Injury & Poisoning',
    'Symptoms,Signs and Ill-defined Conditions'
]

# F1-Scores for Training
f1_scores_fcnn_train = [0.57, 0.47, 0.94, 0.53, 0.74, 0.71, 0.77, 0.88, 0.53, 0.62, 0.56]
f1_scores_fcnn_attention_train = [0.69, 0.55, 0.94, 0.55, 0.74, 0.71, 0.77, 0.88, 0.55, 0.63, 0.55]
f1_scores_fcnn_attention_keras_tuning_train = [0.71 ,0.61 ,0.94 ,0.62 ,0.77 ,0.73 ,0.79 ,0.90 ,0.62 ,0.69 ,0.64]
f1_scores_fcnn_attention_random_search_train = [0.77, 0.56, 0.95, 0.59, 0.73, 0.73, 0.80, 0.89, 0.60, 0.66, 0.61]

# Plotting Training F1-Scores
plt.figure(figsize=(12, 6))
plt.plot(labels, f1_scores_fcnn_train, marker='o', linestyle='-', label='FCNN')
plt.plot(labels, f1_scores_fcnn_attention_train, marker='s', linestyle='--', label='FCNN with Attention')
plt.plot(labels, f1_scores_fcnn_attention_keras_tuning_train, marker='^', linestyle='-.', label='FCNN + Attention Keras Tuning')
plt.plot(labels, f1_scores_fcnn_attention_random_search_train, marker='x', linestyle=':', label='FCNN + Attention Random Search')
plt.title('Training F1-Scores of FCNN Models for Each Condition')
plt.xlabel('Conditions')
plt.ylabel('F1-Score')
plt.ylim(0.4, 1)
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()

# F1-Scores for Testing
f1_scores_fcnn_test = [0.66, 0.45, 0.94, 0.51, 0.74, 0.69, 0.74, 0.88, 0.49, 0.59, 0.52]
f1_scores_fcnn_attention_test = [0.72, 0.53, 0.94, 0.53, 0.74, 0.69, 0.75, 0.89, 0.51, 0.60, 0.52]
f1_scores_fcnn_attention_keras_tuning_test = [0.71 ,0.57 ,0.94 ,0.57 ,0.75 ,0.71 ,0.77 ,0.90 ,0.59 ,0.66 ,0.62]
f1_scores_fcnn_attention_random_search_test = [0.72, 0.54, 0.94, 0.57, 0.70, 0.71, 0.77, 0.89, 0.55, 0.63, 0.57]

# Plotting Testing F1-Scores
plt.figure(figsize=(12, 6))
plt.plot(labels, f1_scores_fcnn_test, marker='o', linestyle='-', label='FCNN')
plt.plot(labels, f1_scores_fcnn_attention_test, marker='s', linestyle='--', label='FCNN with Attention')
plt.plot(labels, f1_scores_fcnn_attention_keras_tuning_test, marker='^', linestyle='-.', label='FCNN + Attention Keras Tuning')
plt.plot(labels, f1_scores_fcnn_attention_random_search_test, marker='x', linestyle=':', label='FCNN + Attention Random Search')
plt.title('Testing F1-Scores of FCNN Models for Each Condition')
plt.xlabel('Conditions')
plt.ylabel('F1-Score')
plt.ylim(0.4, 1)
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()
